# %%
#importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
import pandas as pd
import openpyxl
from openpyxl import load_workbook,Workbook
from openpyxl.styles import PatternFill
warnings.filterwarnings("ignore")

# %%
data=pd.read_excel('Data/Temp.xlsx')
data.head()
# Out:
#    SrNo    SiteFeature AttributeOrParameter StationOrSiteName  \
# 0   120  Surface Water                 Temp          Ambeghar
# 1   121  Surface Water                 Temp          Ambeghar
# 2   122  Surface Water                 Temp          Ambeghar
# 3   123  Surface Water                 Temp          Ambeghar
# 4   124  Surface Water                 Temp          Ambeghar
#
#   PeriodOrDateofMeasurment  Temp SampleSource  SampleDepth
# 0      2018-01-10 09:15:00  22.0        River         30.0
# 1      2018-02-06 15:10:00  22.5        River         30.0
# 2      2018-03-15 09:20:00  23.0        River         30.0
# 3      2018-04-11 09:20:00  23.5        River         30.0
# 4      2018-05-09 10:10:00  28.0        River         30.0

# %%
data.SiteFeature.unique()
# Out:
# array(['Surface Water'], dtype=object)

# %%
data.SampleDepth.unique()
# Out:
# array([30., nan])

# %%
data.StationOrSiteName.unique()
# Out:
# array(['Ambeghar', 'Chaskman', 'Dattawadi', 'Daund',
#        'Khadakwasla Reservoir', 'Ambegaon', 'Khamgaon', 'Narsinhpur',
#        'Nighoje', 'Panshet Reservoir', 'Paud', 'Pavana Reservoir',
#        'Pimpale Gurav', 'Rakshewadi'], dtype=object)

# %%
data.SampleSource.unique()
# Out:
# array(['River', 'Reservoir'], dtype=object)

# %%
#dropping Features having only unique or same value
data.drop(['SrNo','AttributeOrParameter','SiteFeature','SampleDepth'],axis=1,inplace=True)

# %%
data.columns=['Station','Period','Temp','SampleSource']

# %%
data.head()
# Out:
#     Station              Period  Temp SampleSource
# 0  Ambeghar 2018-01-10 09:15:00  22.0        River
# 1  Ambeghar 2018-02-06 15:10:00  22.5        River
# 2  Ambeghar 2018-03-15 09:20:00  23.0        River
# 3  Ambeghar 2018-04-11 09:20:00  23.5        River
# 4  Ambeghar 2018-05-09 10:10:00  28.0        River

# %%
data=data.sort_values(by=['Period'])
x=np.arange(916)
data.index=x

# %%
data.head(10)
# Out:
#          Station              Period  Temp SampleSource
# 0       Khamgaon 2011-01-06 13:00:00  26.0        River
# 1      Dattawadi 2011-01-10 11:20:00  26.0        River
# 2           Paud 2011-01-10 13:40:00  27.0        River
# 3          Daund 2011-01-12 12:10:00  25.0        River
# 4     Narsinhpur 2011-01-15 12:00:00  26.0        River
# 5       Ambeghar 2011-01-18 13:15:00  26.0        River
# 6       Chaskman 2011-01-27 14:45:00  27.0        River
# 7  Pimpale Gurav 2011-01-29 13:30:00  25.0        River
# 8        Nighoje 2011-01-29 15:20:00  25.0        River
# 9       Ambeghar 2011-02-03 12:30:00  27.0        River

# %%
plt.plot(data['Temp'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 916 entries, 0 to 915
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Station       916 non-null    object
#  1   Period        916 non-null    datetime64[ns]
#  2   Temp          916 non-null    float64
#  3   SampleSource  916 non-null    object
# dtypes: datetime64[ns](1), float64(1), object(2)
# memory usage: 35.8+ KB

# %%
data.shape
# Out:
# (916, 4)

# %%
data.Station.value_counts()
# Out:
# Khamgaon                 118
# Khadakwasla Reservoir    117
# Panshet Reservoir        115
# Pavana Reservoir         115
# Ambeghar                 106
# Paud                      75
# Chaskman                  73
# Daund                     68
# Ambegaon                  50
# Rakshewadi                36
# Narsinhpur                32
# Nighoje                    5
# Dattawadi                  4
# Pimpale Gurav              2
# Name: Station, dtype: int64

# %%
data.replace(['Pimpale Gurav','Dattawadi','Nighoje','Narsinhpur','Rakshewadi'], 'Others',inplace=True)

# %%
data.head()
# Out:
#     Station              Period  Temp SampleSource
# 0  Khamgaon 2011-01-06 13:00:00  26.0        River
# 1    Others 2011-01-10 11:20:00  26.0        River
# 2      Paud 2011-01-10 13:40:00  27.0        River
# 3     Daund 2011-01-12 12:10:00  25.0        River
# 4    Others 2011-01-15 12:00:00  26.0        River

# %%
data.Station.value_counts()
# Out:
# Khamgaon                 118
# Khadakwasla Reservoir    117
# Panshet Reservoir        115
# Pavana Reservoir         115
# Ambeghar                 106
# Others                    79
# Paud                      75
# Chaskman                  73
# Daund                     68
# Ambegaon                  50
# Name: Station, dtype: int64

# %%
data.SampleSource.value_counts()
# Out:
# River        571
# Reservoir    345
# Name: SampleSource, dtype: int64

# %%
#One hot Encoding
data=pd.get_dummies(data,columns=['Station','SampleSource'],drop_first=True)

# %%
data.head()
# Out:
#                Period  Temp  Station_Ambeghar  Station_Chaskman  \
# 0 2011-01-06 13:00:00  26.0                 0                 0
# 1 2011-01-10 11:20:00  26.0                 0                 0
# 2 2011-01-10 13:40:00  27.0                 0                 0
# 3 2011-01-12 12:10:00  25.0                 0                 0
# 4 2011-01-15 12:00:00  26.0                 0                 0
#
#    Station_Daund  Station_Khadakwasla Reservoir  Station_Khamgaon  \
# 0              0                              0                 1
# 1              0                              0                 0
# 2              0                              0                 0
# 3              1                              0                 0
# 4              0                              0                 0
#
#    Station_Others  Station_Panshet Reservoir  Station_Paud  \
# 0               0                          0             0
# 1               1                          0             0
# 2               0                          0             1
# 3               0                          0             0
# 4               1                          0             0
#
#    Station_Pavana Reservoir  SampleSource_River
# 0                         0                   1
# 1                         0                   1
# 2                         0                   1
# 3                         0                   1
# 4                         0                   1

# %%
# Handling DateTime
data['Date']=data['Period'].dt.day
data['Month']=data['Period'].dt.month
data['Year']=data['Period'].dt.year
data.drop('Period',axis=1,inplace=True)

# %%
data.head()
# Out:
#    Temp  Station_Ambeghar  Station_Chaskman  Station_Daund  \
# 0  26.0                 0                 0              0
# 1  26.0                 0                 0              0
# 2  27.0                 0                 0              0
# 3  25.0                 0                 0              1
# 4  26.0                 0                 0              0
#
#    Station_Khadakwasla Reservoir  Station_Khamgaon  Station_Others  \
# 0                              0                 1               0
# 1                              0                 0               1
# 2                              0                 0               0
# 3                              0                 0               0
# 4                              0                 0               1
#
#    Station_Panshet Reservoir  Station_Paud  Station_Pavana Reservoir  \
# 0                          0             0                         0
# 1                          0             0                         0
# 2                          0             1                         0
# 3                          0             0                         0
# 4                          0             0                         0
#
#    SampleSource_River  Date  Month  Year
# 0                   1     6      1  2011
# 1                   1    10      1  2011
# 2                   1    10      1  2011
# 3                   1    12      1  2011
# 4                   1    15      1  2011

# %%
data.columns=['Temp', 'Ambeghar', 'Chaskman', 'Daund',
       'Khadakwasla_Reservoir', 'Khamgaon', 'Others',
       'Panshet_Reservoir', 'Paud', 'Pavana_Reservoir',
       'River', 'Date', 'Month', 'Year']

# %%
data=data[['Date', 'Month', 'Year','Ambeghar', 'Chaskman', 'Daund',
       'Khadakwasla_Reservoir', 'Khamgaon', 'Others',
       'Panshet_Reservoir', 'Paud', 'Pavana_Reservoir',
       'River','Temp']]

# %%
data.head()
# Out:
#    Date  Month  Year  Ambeghar  Chaskman  Daund  Khadakwasla_Reservoir  \
# 0     6      1  2011         0         0      0                      0
# 1    10      1  2011         0         0      0                      0
# 2    10      1  2011         0         0      0                      0
# 3    12      1  2011         0         0      1                      0
# 4    15      1  2011         0         0      0                      0
#
#    Khamgaon  Others  Panshet_Reservoir  Paud  Pavana_Reservoir  River  Temp
# 0         1       0                  0     0                 0      1  26.0
# 1         0       1                  0     0                 0      1  26.0
# 2         0       0                  0     1                 0      1  27.0
# 3         0       0                  0     0                 0      1  25.0
# 4         0       1                  0     0                 0      1  26.0

# %%
data.corr()
# Out:
#                            Date     Month      Year  Ambeghar  Chaskman  \
# Date                   1.000000  0.079456  0.039521  0.027659  0.082769
# Month                  0.079456  1.000000 -0.084850 -0.070877  0.016942
# Year                   0.039521 -0.084850  1.000000 -0.009269  0.084052
# Ambeghar               0.027659 -0.070877 -0.009269  1.000000 -0.106453
# Chaskman               0.082769  0.016942  0.084052 -0.106453  1.000000
# Daund                  0.074858  0.119496 -0.074914 -0.102439 -0.083331
# Khadakwasla_Reservoir -0.076699 -0.015185  0.015468 -0.138430 -0.112607
# Khamgaon               0.010704 -0.021571  0.008263 -0.139107 -0.113159
# Others                 0.072433  0.051393 -0.095444 -0.111138 -0.090406
# Panshet_Reservoir     -0.075330 -0.015045  0.008587 -0.137070 -0.111501
# Paud                  -0.060839 -0.038182 -0.000559 -0.108030 -0.087878
# Pavana_Reservoir      -0.063014 -0.015045  0.008587 -0.137070 -0.111501
# River                  0.148056  0.032879 -0.024217  0.281191  0.228738
# Temp                   0.109384  0.051398  0.065743 -0.095883 -0.139850
#
#                           Daund  Khadakwasla_Reservoir  Khamgaon    Others  \
# Date                   0.074858              -0.076699  0.010704  0.072433
# Month                  0.119496              -0.015185 -0.021571  0.051393
# Year                  -0.074914               0.015468  0.008263 -0.095444
# Ambeghar              -0.102439              -0.138430 -0.139107 -0.111138
# Chaskman              -0.083331              -0.112607 -0.113159 -0.090406
# Daund                  1.000000              -0.108362 -0.108892 -0.086998
# Khadakwasla_Reservoir -0.108362               1.000000 -0.147150 -0.117563
# Khamgaon              -0.108892              -0.147150  1.000000 -0.118138
# Others                -0.086998              -0.117563 -0.118138  1.000000
# Panshet_Reservoir     -0.107297              -0.144995 -0.145704 -0.116408
# Paud                  -0.084565              -0.114275 -0.114834 -0.091745
# Pavana_Reservoir      -0.107297              -0.144995 -0.145704 -0.116408
# River                  0.220114              -0.492298  0.298904  0.238804
# Temp                   0.064544               0.011503  0.057438  0.117458
#
#                        Panshet_Reservoir      Paud  Pavana_Reservoir  \
# Date                           -0.075330 -0.060839         -0.063014
# Month                          -0.015045 -0.038182         -0.015045
# Year                            0.008587 -0.000559          0.008587
# Ambeghar                       -0.137070 -0.108030         -0.137070
# Chaskman                       -0.111501 -0.087878         -0.111501
# Daund                          -0.107297 -0.084565         -0.107297
# Khadakwasla_Reservoir          -0.144995 -0.114275         -0.144995
# Khamgaon                       -0.145704 -0.114834         -0.145704
# Others                         -0.116408 -0.091745         -0.116408
# Panshet_Reservoir               1.000000 -0.113153         -0.143571
# Paud                           -0.113153  1.000000         -0.113153
# Pavana_Reservoir               -0.143571 -0.113153          1.000000
# River                          -0.480663  0.232126         -0.480663
# Temp                            0.104482 -0.028295         -0.056634
#
#                           River      Temp
# Date                   0.148056  0.109384
# Month                  0.032879  0.051398
# Year                  -0.024217  0.065743
# Ambeghar               0.281191 -0.095883
# Chaskman               0.228738 -0.139850
# Daund                  0.220114  0.064544
# Khadakwasla_Reservoir -0.492298  0.011503
# Khamgaon               0.298904  0.057438
# Others                 0.238804  0.117458
# Panshet_Reservoir     -0.480663  0.104482
# Paud                   0.232126 -0.028295
# Pavana_Reservoir      -0.480663 -0.056634
# River                  1.000000 -0.038331
# Temp                  -0.038331  1.000000

# %%
X=data.drop('Temp',axis=1)
Y=data['Temp']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.3,random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error,r2_score
import math

regressor = RandomForestRegressor(n_estimators = 100, random_state = 0)
 
regressor.fit(x_train, y_train)
pred=regressor.predict(x_test)
print('RMSE : ',math.sqrt(mean_squared_error(y_test,pred)))
print('R2 : ',(r2_score(y_test,pred)*100))
# Out:
# RMSE :  1.3956564817039534
# R2 :  68.53215608946094

# %%
parameter=pd.read_excel('Input/Input.xlsx')
temp=regressor.predict(parameter)
temp=pd.DataFrame(temp)
temp.columns=['Temp']
output=pd.concat([parameter,temp],axis=1)
output.to_csv('Output/Output_Temp.csv')
